# %%
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 394.4 MB 28 kB/s  eta 0:00:014     |██████████████████████          | 271.3 MB 3.7 MB/s eta 0:00:34
# ...
#      |████████████████████████████████| 1.0 MB 3.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.6 MB 519 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 462 kB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 1.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8 MB 11.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 127 kB 8.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 1.4 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 3.5 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 136 kB 5.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 781 kB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 6.7 MB/s eta 0:00:01
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing

# %%
(features, actual_prices), _ = boston_housing.load_data(test_split=0)
# Out:
# ...
# 57344/57026 [==============================] - 0s 1us/step

# %%
features.shape, actual_prices.shape
# Out:
# ((506, 13), (506,))

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization

model = Sequential()
model.add(BatchNormalization(input_shape=(features.shape[1],)))
model.add(Dense(8, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1))

model.compile(optimizer='sgd', loss='mse')

model.fit(features, actual_prices, epochs=100, validation_split=0.35)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 26ms/step - loss: 312.9281 - val_loss: 140.0072
# Epoch 2/100
# 11/11 [==============================] - 0s 7ms/step - loss: 85.8461 - val_loss: 886.8629
# Epoch 3/100
# 11/11 [==============================] - 0s 7ms/step - loss: 34.3464 - val_loss: 79.7736
# Epoch 4/100
# 11/11 [==============================] - 0s 7ms/step - loss: 88.6003 - val_loss: 975.1644
# Epoch 5/100
# 11/11 [==============================] - 0s 7ms/step - loss: 80.0888 - val_loss: 110.7840
# Epoch 6/100
# 11/11 [==============================] - 0s 7ms/step - loss: 57.3903 - val_loss: 66.5414
# Epoch 7/100
# 11/11 [==============================] - 0s 7ms/step - loss: 76.2959 - val_loss: 28.9257
# Epoch 8/100
# 11/11 [==============================] - 0s 7ms/step - loss: 41.1503 - val_loss: 98.0846
# Epoch 9/100
# 11/11 [==============================] - 0s 7ms/step - loss: 79.5187 - val_loss: 1031.8911
# Epoch 10/100
# ...

# %%
# y_test_predict = model.predict(X_test)
y_train_predict = model.predict(features)

# %%
print('Training Score: ', model.score(features, y_train))
