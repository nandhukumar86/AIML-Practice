# %%
import numpy as np
import pandas as pd

# %%
cars = pd.read_csv("mtcars.csv")

# %%
cars.head(3)
# Out:
#             name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %%
cars.columns
# Out:
# Index(['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
pd.DataFrame(cars.groupby(by='gear').mean()).query('mpg > 21')
# Out:
#             mpg       cyl        disp     hp      drat        wt    qsec  \
# gear
# 4     24.533333  4.666667  123.016667   89.5  4.043333  2.616667  18.965
# 5     21.380000  6.000000  202.480000  195.6  3.916000  2.632600  15.640
#
#             vs        am      carb
# gear
# 4     0.833333  0.666667  2.333333
# 5     0.200000  1.000000  4.400000

# %%
cars.groupby(by='gear').mean().query('mpg > 21')
# Out:
#             mpg       cyl        disp     hp      drat        wt    qsec  \
# gear
# 4     24.533333  4.666667  123.016667   89.5  4.043333  2.616667  18.965
# 5     21.380000  6.000000  202.480000  195.6  3.916000  2.632600  15.640
#
#             vs        am      carb
# gear
# 4     0.833333  0.666667  2.333333
# 5     0.200000  1.000000  4.400000

# %%
cars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cars.query('cyl == 8 & hp > 150').groupby(['gear', 'disp']).mean().query('wt > 4')
# Out:
#              mpg  cyl   hp  drat     wt   qsec  vs  am  carb
# gear disp
# 3    440.0  14.7    8  230  3.23  5.345  17.42   0   0     4
#      460.0  10.4    8  215  3.00  5.424  17.82   0   0     4
#      472.0  10.4    8  205  2.93  5.250  17.98   0   0     4

# %%
cars.iloc[:,4:6]
# Out:
#      hp  drat
# 0   110  3.90
# 1   110  3.90
# 2    93  3.85
# 3   110  3.08
# 4   175  3.15
# 5   105  2.76
# 6   245  3.21
# 7    62  3.69
# 8    95  3.92
# 9   123  3.92
# 10  123  3.92
# 11  180  3.07
# 12  180  3.07
# 13  180  3.07
# 14  205  2.93
# 15  215  3.00
# 16  230  3.23
# 17   66  4.08
# 18   52  4.93
# 19   65  4.22
# 20   97  3.70
# 21  150  2.76
# 22  150  3.15
# 23  245  3.73
# 24  175  3.08
# 25   66  4.08
# 26   91  4.43
# 27  113  3.77
# 28  264  4.22
# 29  175  3.62
# 30  335  3.54
# 31  109  4.11

# %%
cars['gear'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
cars.groupby('gear').mean().query('mpg > 20')
# Out:
#             mpg       cyl        disp     hp      drat        wt    qsec  \
# gear
# 4     24.533333  4.666667  123.016667   89.5  4.043333  2.616667  18.965
# 5     21.380000  6.000000  202.480000  195.6  3.916000  2.632600  15.640
#
#             vs        am      carb
# gear
# 4     0.833333  0.666667  2.333333
# 5     0.200000  1.000000  4.400000

# %%
cars.plot.scatter('mpg','hp')
